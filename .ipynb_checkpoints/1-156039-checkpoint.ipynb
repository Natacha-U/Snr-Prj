# %%
import numpy as np
import matplotlib.pyplot as plt
from astropy.io import fits
from matplotlib import cm
from io import StringIO
import pandas as pd

# %%
mangaid = ['1-156039', '1-22948', '1-258599', '1-269632', '1-284293', '1-43214', '1-574402', '1-72322']
nsa_z =   [0.114699,    0.119399,  0.125582,   0.131457,   0.129080,   0.117997,  0.131997,   0.126168]
BHMASS = []

# %%
drpall_list = fits.open("/Users/natachaupra/Desktop/Snr_Prj/Snr-Prj/platelist-v2_4_3.fits")

# %%
objlist = drpall_list[2].data

# %%
# Compare p james' mangaid with drpall mangaid to get the plateifu number 
plateifu = {}
# lst = []
for i in range(len(objlist)):
    if objlist[i][3] in mangaid:
        if objlist[i][3] in plateifu:
            plateifu[objlist[i][3]].append(objlist[i][2])
        else:
            plateifu[objlist[i][3]] = [objlist[i][2]]

# %%
plateifu
# Out:
# {'1-156039': ['8439-3704'],
#  '1-72322': ['8143-6101'],
#  '1-574402': ['8137-3702'],
#  '1-269632': ['9049-1901'],
#  '1-284293': ['8318-6102'],
#  '1-22948': ['7992-9102'],
#  '1-258599': ['8464-6101'],
#  '1-43214': ['8135-1902']}

# %%
# open the file
data = fits.open('/Users/natachaupra/Downloads/manga-8439-3704-LOGCUBE.fits.gz')

# %%
# retrieve the flux density values
flux = np.transpose(data['FLUX'].data, axes = (2, 1, 0))

# %%
# retrieve the ivar values
ivar = np.transpose(data['IVAR'].data, axes = (2, 1, 0))

# %%
# retrieve the mask values 
mask = np.transpose(data['MASK'].data, axes = (2, 1, 0))

# %%
# retrieve the wave values 
wave = data['WAVE'].data

# %%
# retrieve the flux header values...but why tho ?
flux_header = data['FLUX'].header

# %%
# sum flux density values element wise to get total flux density
n = len(flux)
sumflux = np.zeros(4563)
    
for i in range(n):
    for j in range(n):
        sumflux = np.add(sumflux, flux[i,j])

# %%
# check the redhsift
a = 5007 * (1 + nsa_z[0])

# %%
# select peak region
yaxis = np.where(np.logical_and(wave > 5578, wave < 5585))[0]
print(yaxis)

for i in yaxis:
    print(wave[i])
# Out:
# [1876 1877 1878 1879 1880 1881]
# 5578.27602141201
# 5579.560614821764
# 5580.845504054144
# 5582.130689177262
# 5583.416170259268
# 5584.701947368307

# %%
flux_compare = [] 
ivar_compare = []

for i in yaxis:
    flux_compare.append(flux[:,:,i].flatten())
    ivar_compare.append(ivar[:,:,i].flatten())

flux_compare = np.array(flux_compare)
ivar_compare = np.array(ivar_compare)

len(flux_compare[0]), len(ivar_compare)
# Out:
# (1936, 6)

# %%
result = []
sumresult = []

for i in range(len(yaxis)):
    for j in range(len(flux)**2):
        sigma = np.sqrt(1 / ivar_compare[i][j]) if ivar_compare[i][j] != 0 else 0
        
        if flux_compare[i][j] < (3 * sigma):
            result.append(0)
        else:
            result.append(flux_compare[i][j])
    sumresult.append(np.sum(result))
    result = []

# %%
plt.figure(figsize = (18,10))
plt.grid()
plt.ylim(-1200,1000)
plt.xlim(5575, 5584)
plt.xlabel('Observed Wavelength ' + r'[$\AA$]')
plt.ylabel('Flux Density [1E-17 erg/sec/'+r'$cm^2$/'+r'$\AA$]')
plt.title('MaNGA ID = ' + mangaid[0])
plt.plot(wave, sumflux, color = 'limegreen', linewidth = 3)
plt.plot(wave[yaxis[0] : yaxis[-1] + 1], sumresult, color = 'darkturquoise', linewidth = 3)

# %% [markdown]
# # Fix everything below this cell

# %%
# get peak threshold value
threshold = sumflux[1880]

# %%
plt.figure(figsize = (18,10))
plt.grid()
plt.ylim(-500,1000)
plt.xlim(5575, 5584)
plt.xlabel('Observed Wavelength ' + r'[$\AA$]')
plt.ylabel('Flux Density [1E-17 erg/sec/'+r'$cm^2$/'+r'$\AA$]')
plt.title('MaNGA ID = ' + mangaid[0])
# plt.axvline(a, color = 'mediumpurple', linewidth = 2, label = '5007 * (1+z)')
plt.axvline(wave[yaxis[-2]], color = 'dodgerblue', linewidth = 3, label = str(wave[yaxis[-2]]))
plt.axvline(5579.560614821764, color = 'violet', linewidth = 3, label = '5579.560614821764')
plt.axvline(5580.845504054144, color = 'gold', linewidth = 3, label = '5580.845504054144')
plt.axhline(sumflux[1880], color = 'tomato', linewidth = 3, label = 'threshold')
plt.axhline(0, color = 'k', linewidth = 3)
plt.legend()
plt.plot(wave, sumflux, color = 'limegreen', linewidth = 3)

x = [wave[1877], wave[1878]]
y = [sumflux[1877], sumflux[1878]]

for i_x, i_y in zip(x, y):
    plt.text(i_x, i_y, '({}, {})'.format(i_x, i_y))

# %%
m = (y[1] - y[0])/(x[1] - x[0])
m, sumflux[1880]
# Out:
# (726.2085039776714, 114.32061469986365)

# %%
c = y[0] - m*x[0]
c
# Out:
# -4052264.8349365373

# %%
def func(y, m, c):
    x = (y - c)/m
    return x

# %%
xval = func(sumflux[1880], m, c)
xval
# Out:
# 5580.186865555949

# %%
plt.figure(figsize = (15, 8))
plt.grid()
plt.plot(x, y, color = 'darkgoldenrod', linewidth = 3)
plt.axhline(sumflux[1880], color = 'tomato', linewidth = 3, label = 'threshold')
plt.axhline(0, color = 'k', linewidth = 3, label = '0')
plt.legend()
# for i_x, i_y in zip(x, y):
#     plt.text(i_x, i_y, '({}, {})'.format(i_x, i_y))
plt.plot(xval, sumflux[1880], marker = 'h', ms = 10, color = 'limegreen')

# %% [markdown]
# ##### This point is based entirely on calculations, it may not be correct since god knows if we'll get this value from observation or not.

# %%
xcoord = [xval, wave[1878], wave[1879], wave[1880]]
ycoord = [sumflux[1880], sumflux[1878], sumflux[1879], sumflux[1880]]
xcoord, ycoord
# Out:
# ([5580.186865555949, 5580.845504054144, 5582.130689177262, 5583.416170259268],
#  [114.32061469986365,
#   592.6294931359589,
#   399.4120802208781,
#   114.32061469986365])

# %%
plt.figure(figsize = (18,10))
plt.grid()
plt.ylim(-500,1000)
plt.xlim(5575, 5584)
plt.xlabel('Observed Wavelength ' + r'[$\AA$]')
plt.ylabel('Flux Density [1E-17 erg/sec/'+r'$cm^2$/'+r'$\AA$]')
plt.title('MaNGA ID = ' + mangaid[0])
# plt.axvline(a, color = 'mediumpurple', linewidth = 2, label = '5007 * (1+z)')
# plt.axvline(wave[yaxis[-2]], color = 'dodgerblue', linewidth = 3, label = str(wave[yaxis[-2]]))
# plt.axvline(5579.560614821764, color = 'violet', linewidth = 3, label = '5579.560614821764')
# plt.axvline(5580.845504054144, color = 'gold', linewidth = 3, label = '5580.845504054144')
plt.axhline(sumflux[1880], color = 'tomato', linewidth = 3, label = 'threshold')
plt.axhline(0, color = 'k', linewidth = 3)
plt.legend()
plt.plot(wave, sumflux, color = 'limegreen', linewidth = 3)

for i in xcoord:
    plt.axvline(i, color = 'skyblue', linewidth = 3)

plt.plot(xcoord, ycoord, marker = 'h', ms = 10, color = 'mediumorchid')

# %%
dlmd = []
for i in range(len(xcoord)-1):
    dlmd.append(xcoord[i+1] - xcoord[i])
    
print(dlmd)
# Out:
# [0.6586384981947049, 1.2851851231180262, 1.2854810820062994]

# %% [markdown]
# <img src = 'Images/1-156039trapezium.jpeg'>

# %%
area = (1/2) * (ycoord[0]*dlmd[0] + ycoord[1]*(dlmd[0] + dlmd[1]) + ycoord[2]*(dlmd[1]+dlmd[2]) 
                + ycoord[3]*dlmd[2])
area
# Out:
# 1200.4876447225527

# %%
subtract = ycoord[0] * (xcoord[-1] - xcoord[0])
subtract
# Out:
# 369.1760987365924

# %%
fluxarea = area - subtract
fluxarea
# Out:
# 831.3115459859603

# %%
def Mpc_to_cm(Mpc):
    return Mpc * 3.08568*(10**24)

# %%
redshift = nsa_z[0]
redshift
# Out:
# 0.114699

# %%
luminosity_distance = Mpc_to_cm(533.1)
luminosity_distance
# Out:
# 1.644976008e+27

# %%
def luminosity_calc(luminosity_distance, fluxarea):
    return 4 * np.pi * (luminosity_distance**2) * fluxarea * (1e-17)

# %%
luminosity = luminosity_calc(luminosity_distance, fluxarea)
print(luminosity, ('erg/s (?)'))
# Out:
# 2.8267852251711487e+41 erg/s (?)

# %%
sol_mass = 2 * (10**30)
lmd_edd = 1
sol_luminosity = 3.846 * 10**33

# %%
def BH_calc(luminosity):
    return (3200 * luminosity) / (sol_luminosity * lmd_edd * 3.28 * (10**4))

# %%
print('M_BH / M_sol =',BH_calc(luminosity))
print('log(luminosity) =',np.log10(luminosity))
print('log(M_BH / M_sol) =', np.log10(BH_calc(luminosity)))
print('log(luminosity / sol_lum) =', np.log10(luminosity / sol_luminosity))
# Out:
# M_BH / M_sol = 7170668.861334928
# log(luminosity) = 41.45129281271082
# log(M_BH / M_sol) = 6.855559667416581
# log(luminosity / sol_lum) = 7.866283532808354

# %%
BHMASS.append(np.log10(luminosity / sol_luminosity))

# %%
BHMASS
# Out:
# [7.866283532808354]
