# %%
import numpy as np
import matplotlib.pyplot as plt
from astropy.io import fits
from matplotlib import cm
from io import StringIO
import pandas as pd

# %%
mangaid = '1-22948'
nsa_z = 0.119399
BHMASS = [7.866283532808354]
plateifu = '7992-9102'

# %%
data = fits.open('/Users/natachaupra/Downloads/manga-7992-9102-LOGCUBE.fits.gz')

# %%
flux = np.transpose(data['FLUX'].data, axes = (2, 1, 0))

# %%
ivar = np.transpose(data['IVAR'].data, axes = (2, 1, 0))

# %%
mask = np.transpose(data['MASK'].data, axes = (2, 1, 0))

# %%
wave = data['WAVE'].data

# %%
flux_header = data['FLUX'].header

# %%
n = len(flux)
sumflux = np.zeros(4563)
    
for i in range(n):
    for j in range(n):
        sumflux = np.add(sumflux, flux[i,j])

# %%
a = 5007 * (1 + nsa_z)

# %%
yaxis = np.where(np.logical_and(wave > 5586, wave < 5620))[0]
print(yaxis), print(len(yaxis))

for i in yaxis:
    print(wave[i])
# Out:
# [1883 1884 1885 1886 1887 1888 1889 1890 1891 1892 1893 1894 1895 1896
#  1897 1898 1899 1900 1901 1902 1903 1904 1905 1906 1907 1908]
# 26
# 5587.2743899402
# 5588.561055539444
# 5589.848017438496
# 5591.135275705602
# 5592.422830408998
# 5593.7106816169635
# 5594.998829397764
# 5596.287273819709
# 5597.576014951099
# 5598.865052860273
# 5600.154387615563
# 5601.444019285339
# 5602.733947937972
# 5604.024173641845
# 5605.314696465377
# 5606.60551647698
# 5607.8966337451
# 5609.188048338182
# 5610.479760324706
# 5611.771769773147
# 5613.064076752015
# 5614.356681329818
# 5615.649583575098
# 5616.942783556393
# 5618.236281342279
# 5619.530077001323

# %%
flux_compare = [] 
ivar_compare = []

for i in yaxis:
    flux_compare.append(flux[:,:,i].flatten())
    ivar_compare.append(ivar[:,:,i].flatten())

flux_compare = np.array(flux_compare)
ivar_compare = np.array(ivar_compare)

len(flux_compare[0]), len(ivar_compare)
# Out:
# (4096, 26)

# %%
result = []
sumresult = []

for i in range(len(yaxis)):
    for j in range(len(flux)**2):
        sigma = np.sqrt(1 / ivar_compare[i][j]) if ivar_compare[i][j] != 0 else 0
        
        if flux_compare[i][j] < (3 * sigma):
            result.append(0)
        else:
            result.append(flux_compare[i][j])
    sumresult.append(np.sum(result))
    result = []

# %%
plt.figure(figsize = (18,10))
plt.grid()
plt.ylim(0,200)
plt.xlim(5575, 5640)
plt.xlabel('Observed Wavelength ' + r'[$\AA$]')
plt.ylabel('Flux Density [1E-17 erg/sec/'+r'$cm^2$/'+r'$\AA$]')
plt.title('MaNGA ID = ' + mangaid[0])
plt.plot(wave, sumflux, color = 'limegreen', linewidth = 3)
plt.plot(wave[yaxis[0] : yaxis[-1] + 1], sumresult, color = 'darkturquoise', linewidth = 3)

# %% [markdown]
# # Fix everything below this cell

# %%
plt.figure(figsize = (18,10))
plt.grid()
plt.ylim(0,200)
plt.xlim(5575, 5640)
plt.xlabel('Observed Wavelength ' + r'[$\AA$]')
plt.ylabel('Flux Density [1E-17 erg/sec/'+r'$cm^2$/'+r'$\AA$]')
plt.title('MaNGA ID = ' + mangaid)
plt.plot(wave, sumflux, color = 'limegreen', linewidth = 3)
plt.axvline(a, color = 'orangered', linewidth = 3)

# %%
plt.figure(figsize = (18,10))
plt.grid()
plt.ylim(0,200)
plt.xlim(5575, 5640)
plt.xlabel('Observed Wavelength ' + r'[$\AA$]')
plt.ylabel('Flux Density [1E-17 erg/sec/'+r'$cm^2$/'+r'$\AA$]')
plt.title('MaNGA ID = ' + mangaid)
plt.plot(wave, sumflux, color = 'limegreen', linewidth = 3)
plt.axvline(a, color = 'orangered', linewidth = 3)
plt.axhline(sumflux[1885], color = 'dodgerblue', linewidth = 3)

# %%
plt.figure(figsize = (18,10))
plt.grid()
plt.ylim(90,110)
plt.xlim(5614, 5618)
plt.xlabel('Observed Wavelength ' + r'[$\AA$]')
plt.ylabel('Flux Density [1E-17 erg/sec/'+r'$cm^2$/'+r'$\AA$]')
plt.title('MaNGA ID = ' + mangaid)
plt.plot(wave, sumflux, color = 'limegreen', linewidth = 3)
plt.axvline(a, color = 'orangered', linewidth = 3)
plt.axhline(sumflux[1885], color = 'dodgerblue', linewidth = 3)
plt.axvline(wave[1905], label = '1905', color = 'pink', linewidth = 3)
plt.axvline(wave[1906], label = '1906', color = 'pink', linewidth = 3)
plt.legend()

# %%
x = [wave[1905], wave[1906]]
y = [sumflux[1905], sumflux[1906]]

# %%
m = (y[1] - y[0])/(x[1] - x[0])
m, sumflux[1885]
# Out:
# (-4.0287534825814, 99.21370320083372)

# %%
c = y[0] - m*x[0]
c
# Out:
# 22726.250289688378

# %%
def func(y, m, c):
    x = (y - c)/m
    return x

# %%
xval = func(sumflux[1885], m, c)
xval
# Out:
# 5616.38647892385

# %%
xcoord = []
ycoord = []

for i in range(1885, 1906):
    xcoord.append(wave[i])
    ycoord.append(sumflux[i])
    
xcoord.append(xval)
ycoord.append(sumflux[1885])

# %%
plt.figure(figsize = (18,10))
plt.grid()
plt.ylim(75,200)
plt.xlim(5585, 5620)
plt.xlabel('Observed Wavelength ' + r'[$\AA$]')
plt.ylabel('Flux Density [1E-17 erg/sec/'+r'$cm^2$/'+r'$\AA$]')
plt.title('MaNGA ID = ' + mangaid)
plt.plot(wave, sumflux, color = 'limegreen', linewidth = 3)
plt.axvline(a, color = 'orangered', linewidth = 3)
plt.axhline(sumflux[1885], color = 'dodgerblue', linewidth = 3)
plt.plot(xcoord, ycoord, marker = 'h', ms = 10, color = 'gold')

# %%
plt.figure(figsize = (18,10))
plt.grid()
plt.ylim(75,200)
plt.xlim(5585, 5620)
plt.xlabel('Observed Wavelength ' + r'[$\AA$]')
plt.ylabel('Flux Density [1E-17 erg/sec/'+r'$cm^2$/'+r'$\AA$]')
plt.title('MaNGA ID = ' + mangaid)
plt.plot(wave, sumflux, color = 'limegreen', linewidth = 3)
plt.axvline(a, color = 'orangered', linewidth = 3)
plt.axhline(sumflux[1885], color = 'dodgerblue', linewidth = 3)

for i in xcoord:
    plt.axvline(i, color = 'gold', linewidth = 2)
plt.plot(xcoord, ycoord, marker = 'h', ms = 10, color = 'deeppink')

# %%
dlmd = []
for i in range(len(xcoord)-1):
    dlmd.append(xcoord[i+1] - xcoord[i])
    
print(dlmd)
# Out:
# [1.2872582671061537, 1.2875547033963812, 1.2878512079651045, 1.2881477808005002, 1.2884444219453144, 1.2887411313895427, 1.2890379091741124, 1.2893347552899286, 1.2896316697760994, 1.289928652632625, 1.2902257038731477, 1.2905228235322284, 1.290820011602591, 1.2911172681206153, 1.291414593081754, 1.2917119865242057, 1.2920094484406945, 1.2923069788685098, 1.2926045778021944, 1.2929022452808567, 0.7368953487512044]

# %%
len(ycoord), len(dlmd)
# Out:
# (22, 21)

# %%
# area = y_1 * h_1 + y_last * h_last + the in betweens 
area = ycoord[0] * dlmd[0] + ycoord[-1] * dlmd[-1]
# print(ycoord[0] * dlmd[0])
# print(ycoord[-1] * dlmd[-1])

for i in range(1, len(ycoord)-1):
#     print(i)
    area += ycoord[i] * (dlmd[i-1] + dlmd[i])

finalarea = (1/2) * area
finalarea
# Out:
# 3405.248332274636

# %%
subtract = ycoord[0] * (xcoord[-1] - xcoord[0])
subtract
# Out:
# 2632.9790412146453

# %%
fluxarea = finalarea - subtract
fluxarea
# Out:
# 772.2692910599908

# %%
def Mpc_to_cm(Mpc):
    return Mpc * 3.08568*(10**24)

# %%
nsa_z
# Out:
# 0.119399

# %%
luminosity_distance = Mpc_to_cm(556.7)
luminosity_distance
# Out:
# 1.717798056e+27

# %%
def luminosity_calc(luminosity_distance, fluxarea):
    return 4 * np.pi * (luminosity_distance**2) * fluxarea * (1e-17)

# %%
luminosity = luminosity_calc(luminosity_distance, fluxarea)
print(luminosity, ('erg/s (?)'))
# Out:
# 2.8636691671091227e+41 erg/s (?)

# %%
sol_mass = 2 * (10**30)
lmd_edd = 1
sol_luminosity = 3.846 * 10**33

# %%
def BH_calc(luminosity):
    return (3200 * luminosity) / (sol_luminosity * lmd_edd * 3.28 * (10**4))

# %%
print('M_BH / M_sol =',BH_calc(luminosity))
print('log(luminosity) =',np.log10(luminosity))
print('log(M_BH / M_sol) =', np.log10(BH_calc(luminosity)))
print('log(luminosity / sol_lum) =', np.log10(luminosity / sol_luminosity))
# Out:
# M_BH / M_sol = 7264231.871210184
# log(luminosity) = 41.456922843524765
# log(M_BH / M_sol) = 6.861189698230529
# log(luminosity / sol_lum) = 7.871913563622302

# %%
BHMASS.append(np.log10(luminosity / sol_luminosity))

# %%
BHMASS
# Out:
# [7.866283532808354, 7.871913563622302]
